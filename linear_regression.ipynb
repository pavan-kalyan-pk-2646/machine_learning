# %% [raw]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv("D:/coe/datasets-main/Advertising.csv")

# %%
d.shape
# Out:
# (200, 5)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [raw]
# CHECKING MISSING VALUES

# %%
d.isna()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %% [raw]
# DISTRIBUTION OF HISTOGRAM

# %%
sns.histplot(x=d['TV'],kde=True,bins=40)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=d['Radio'],kde=True,bins=50)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %% [markdown]
# ###

# %%
sns.histplot(x=d['Newspaper'],kde=True,bins=30)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=d['Sales'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
d['TV'].skew()
# Out:
# np.float64(-0.06985336213274573)

# %%
d['Radio'].skew()
# Out:
# np.float64(0.09417463149664404)

# %%
d['Newspaper'].skew()
# Out:
# np.float64(0.8947204074986175)

# %%
d['Sales'].skew()
# Out:
# np.float64(0.4075714250767127)

# %% [raw]
# INSIGHTS
#
#
# TV Advertising:
#
# Skewness Value: -0.0698
# Insight: The data is nearly perfectly symmetrical.
# Interpretation: Since the value is very close to zero, it indicates a highly balanced distribution of advertising spend across the TV category.
#
# Radio Advertising:
#
# Skewness Value: 0.0941
# Insight: The data shows very low positive skewness.
# Interpretation: Like TV, the Radio distribution is almost symmetrical, suggesting a consistent spread of data points without significant bias toward high or low values.
#
# Newspaper Advertising:
#
# Skewness Value: 0.8947
# Insight: The data is moderately positively skewed.
# Interpretation:This indicates a "tail" on the right side of the distribution. Most of the budget is concentrated in lower amounts, with a few instances of very high spending on newspaper ads.
#
# Sales:
#
# Skewness Value: 0.4075
# Insight: The data shows fairly low positive skewness.
# Interpretation: The distribution of sales is relatively healthy and close to normal, though there is a slight tendency toward higher sales figures in some instances.

# %% [raw]
# SCtterplot

# %%
sns.scatterplot(x="TV",y="Sales",data=d)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x="Radio",y="Sales",data=d)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(x="Newspaper",y="Sales",data=d)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.scatterplot(x="Unnamed: 0",y="Sales",data=d)
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Sales'>

# %% [raw]
# CORRELATION INSIGHTS
#
# TV vs. Sales
#
# Relationship: Positive Linear
#
# Nature: As investment in TV advertising increases, Sales show a clear and consistent upward trend.
#
# Data Spread: Points are tightly clustered, indicating a strong correlation.
#
#
#
#
# Radio vs. Sales
#
# Relationship: Positive Linear
#
# Nature: Increased spending on Radio advertising generally leads to higher Sales.
#
# Data Spread: There is more "noise" (scatter) compared to TV, but the overall upward direction is clearly visible.
#
#
#
#
# Newspaper vs. Sales
#
# Relationship: Random
#
# Nature: There is no clear upward or downward trend between Newspaper advertising spend and Sales.
#
# Data Spread: The data points are scattered widely across the plot, suggesting that Sales do not depend strongly on Newspaper ads.
#
#
#
# Unnamed: 0 vs. Sales
#
# Relationship: Random
#
# Nature: The plot shows no discernible pattern, trend line, or cluster.
#
# Data Spread: Points are scattered uniformly across the entire graph.
#
# Interpretation: "Unnamed: 0" (typically representing the row index or Serial Number) has no correlation with Sales; the order of data entry does not affect performance.

# %%
d.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %% [raw]
# TV vs. Sales
#
# Classification: Strong Positive
#
# Correlation Value: 0.782224
#
# Insight: There is a clear, tight linear trend in the scatterplot. As TV advertising spend increases, sales rise significantly, making it the most reliable predictor of revenue.
#
#
#
# Radio vs. Sales
#
# Classification: Moderate/Strong Positive
#
# Correlation Value: 0.576223
#
# Insight: The relationship is positive, but the data points are more dispersed than the TV plot. While higher radio spending generally leads to more sales, it is less predictable than TV.
#
#
# Newspaper vs. Sales
#
# Classification: Weak Positive
#
# Correlation Value: 0.228299
#
# Insight: The scatterplot shows a very loose, almost random distribution of points with only a slight upward lean. Increasing newspaper spend does not guarantee a meaningful increase in sales.
#
#
#
#
# Unnamed: 0 vs. Sales
#
# Classification: Random (Weak Negative)
#
# Correlation Value: -0.051616
#
# Insight: The correlation is near zero, and the scatterplot shows points distributed uniformly across the graph. This confirms that the row index or ID has no statistical impact on sales.

# %%
sns.heatmap(d.corr(),annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
d.drop('Unnamed:0',axis=1,inplace=True)

# %%
X=d.drop('Sales',axis=1)
y=d.Sales

# %% [raw]
# SIMPLE LINEAR REGRESSION

# %%
# step-1 independent and dependent variable creation
X=d[['TV']]
y=d.Sales

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.46138746336817515

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  13.06226628830567
# MAE :  2.990565035759226
# RMSE :  3.6141757412037494

# %%
X=d[['Radio']]
y=d.Sales

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.37864501183785726

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  15.068910882943161
# MAE :  3.268917036469783
# RMSE :  3.881869508747449

# %%
X=d[['Newspaper']]
y=d.Sales

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004906

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  27.096125475528662
# MAE :  3.992290912504232
# RMSE :  5.205393882841976

# %%
X=d[['TV','Radio','Newspaper']]
y=d.Sales

# %%
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.9085774752313167

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  2.217151072541896
# MAE :  1.2114892606469103
# RMSE :  1.4890100982001082

# %%
X=d[['TV','Radio']]
y=d.Sales

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.9086623887492478

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  2.215091775909797
# MAE :  1.210808620492933
# RMSE :  1.4883184390142443

# %% [raw]
# MULTIPLE LINEAR REGRESSION

# %%
X=d[['TV','Radio']]
y=d.Sales

# %%
X
# Out:
#         TV  Radio
# 0    230.1   37.8
# 1     44.5   39.3
# 2     17.2   45.9
# 3    151.5   41.3
# 4    180.8   10.8
# ..     ...    ...
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6
#
# [200 rows x 2 columns]
